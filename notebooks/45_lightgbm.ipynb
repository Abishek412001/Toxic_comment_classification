# %% [markdown]
# # Phase 5 - Step 59: Multi-Label LightGBM

# %%
import sys
sys.path.append('..')

from src.models.lightgbm_model import MultiLabelLightGBM
import numpy as np

model = MultiLabelLightGBM()
X = np.random.randn(10, 5)
y = np.random.randint(0, 2, size=(10, 6))
model.fit(X, y)
print('LGB Prediction Shape:', model.predict(X).shape)
