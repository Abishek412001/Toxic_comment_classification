# %% [markdown]
# # Phase 5 - Step 56: Multinomial Naive Bayes

# %%
import sys
sys.path.append('..')

from src.models.naive_bayes import MultiLabelNaiveBayes
import numpy as np

model = MultiLabelNaiveBayes()
X = np.abs(np.random.randn(10, 5))
y = np.random.randint(0, 2, size=(10, 6))
model.fit(X, y)
print('NB Prediction Shape:', model.predict(X).shape)
