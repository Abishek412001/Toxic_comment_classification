# %% [markdown]
# # Phase 8 - Step 97: Enterprise Production Emotion Pipeline

# %%
import sys
sys.path.append('..')

from src.emotion.production_emotion_pipeline import ProductionEmotionPipeline

pipeline = ProductionEmotionPipeline()
res = pipeline.predict_single('Awesome work!')
print('Production Payload:', pipeline.format_rest_payload(res))
