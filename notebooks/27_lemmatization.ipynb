# %% [markdown]
# # Phase 3 - Step 38: Lemmatization Module

# %%
import sys
sys.path.append('..')

from src.preprocessing.lemmatizer import lemmatize_text

raw = 'running cars and feet'
clean = lemmatize_text(raw, backend='spacy')
print(f'Before: {raw}\nAfter: {clean}')
