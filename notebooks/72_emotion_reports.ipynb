# %% [markdown]
# # Phase 8 - Step 98: Enterprise Emotion Reports & Exports

# %%
import sys
sys.path.append('..')

from src.emotion.emotion_report_generator import EmotionReportGenerator

EmotionReportGenerator.export_markdown({'joy_count': 150}, 'outputs/reports/emotion_test.md')
print('Emotion Reports Exported!')
