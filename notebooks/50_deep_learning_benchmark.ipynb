# %% [markdown]
# # Phase 5 - Step 64: Deep Learning Benchmark Suite

# %%
import sys
sys.path.append('..')

from src.reports.deep_learning_summary import export_deep_learning_report

export_deep_learning_report()
print('Deep Learning Benchmark Exported!')
