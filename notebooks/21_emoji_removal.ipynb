# %% [markdown]
# # Phase 3 - Step 32: Emoji Removal / Conversion Module

# %%
import sys
sys.path.append('..')

from src.preprocessing.emoji_cleaner import remove_emojis

raw = 'Angry text 🤬 🔥'
clean = remove_emojis(raw, demoji_to_text=True)
print(f'Before: {raw}\nAfter: {clean}')
