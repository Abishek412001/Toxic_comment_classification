# %% [markdown]
# # Phase 3 - Step 33: Number Removal Module

# %%
import sys
sys.path.append('..')

from src.preprocessing.number_cleaner import remove_numbers

raw = 'User 123 scored 98.5 percent'
clean = remove_numbers(raw, replacement_token='0')
print(f'Before: {raw}\nAfter: {clean}')
