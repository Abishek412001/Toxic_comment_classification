# %% [markdown]
# # Phase 3 - Step 34: Punctuation Removal Module

# %%
import sys
sys.path.append('..')

from src.preprocessing.punctuation_cleaner import remove_punctuation

raw = 'Hello, world!!! How are you?'
clean = remove_punctuation(raw)
print(f'Before: {raw}\nAfter: {clean}')
