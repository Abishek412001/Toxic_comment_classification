# %% [markdown]
# # Phase 5 - Step 65: Multi-Label BERT Fine-Tuning

# %%
import sys
sys.path.append('..')

from src.models.bert_classifier import MultiLabelBERTClassifier
import numpy as np

model = MultiLabelBERTClassifier()
X = np.random.randn(10, 5)
y = np.random.randint(0, 2, size=(10, 6))
model.fit(X, y)
print('BERT Prediction Shape:', model.predict(X).shape)
