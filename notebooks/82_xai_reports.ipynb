# %% [markdown]
# # Phase 9 - Step 109: Enterprise Explainability Reports & Exports

# %%
import sys
sys.path.append('..')

from src.xai.xai_report_generator import XAIReportGenerator

XAIReportGenerator.export_markdown({'shap_consistency': 0.98}, 'outputs/reports/xai_test.md')
print('XAI Reports Exported!')
