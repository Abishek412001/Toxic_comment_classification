# %% [markdown]
# # Phase 5 - Step 62: Multi-Label Bidirectional LSTM

# %%
import sys
sys.path.append('..')

from src.models.bilstm_model import MultiLabelBiLSTM
import numpy as np

model = MultiLabelBiLSTM()
X = np.random.randn(10, 5)
y = np.random.randint(0, 2, size=(10, 6))
model.fit(X, y)
print('BiLSTM Prediction Shape:', model.predict(X).shape)
