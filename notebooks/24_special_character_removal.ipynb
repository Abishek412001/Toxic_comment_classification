# %% [markdown]
# # Phase 3 - Step 35: Special Character Removal Module

# %%
import sys
sys.path.append('..')

from src.preprocessing.special_character_cleaner import remove_special_characters

raw = 'Clean § © ™ symbol text'
clean = remove_special_characters(raw)
print(f'Before: {raw}\nAfter: {clean}')
