# %% [markdown]
# # Phase 7 - Step 89: Enterprise Sentiment Reports & Exports

# %%
import sys
sys.path.append('..')

from src.sentiment.sentiment_report_generator import SentimentReportGenerator

SentimentReportGenerator.export_markdown({'positive_count': 100}, 'outputs/reports/sentiment_test.md')
print('Sentiment Reports Exported!')
