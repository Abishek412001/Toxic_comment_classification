# %% [markdown]
# # Phase 5 - Step 55: Multi-Label Logistic Regression

# %%
import sys
sys.path.append('..')

from src.models.logistic_regression import MultiLabelLogisticRegression
import numpy as np

model = MultiLabelLogisticRegression()
X = np.random.randn(10, 5)
y = np.random.randint(0, 2, size=(10, 6))
model.fit(X, y)
print('LR Prediction Shape:', model.predict(X).shape)
