# %% [markdown]
# # Phase 5 - Step 66: Multi-Label DistilBERT Fine-Tuning

# %%
import sys
sys.path.append('..')

from src.models.distilbert_classifier import MultiLabelDistilBERTClassifier
import numpy as np

model = MultiLabelDistilBERTClassifier()
X = np.random.randn(10, 5)
y = np.random.randint(0, 2, size=(10, 6))
model.fit(X, y)
print('DistilBERT Prediction Shape:', model.predict(X).shape)
