# %% [markdown]
# # Phase 10 - Step 114: Emotion Analytics Dashboard

# %%
import sys
sys.path.append('..')

from src.visualization.emotion_dashboard import EmotionDashboard

EmotionDashboard.render_emotion_dashboard()
print('Emotion Dashboard Rendered!')
