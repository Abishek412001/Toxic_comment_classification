# %% [markdown]
# # Phase 3 - Step 36: Whitespace Normalization Module

# %%
import sys
sys.path.append('..')

from src.preprocessing.whitespace_normalizer import normalize_whitespace

raw = '  Too   many   spaces \n\t here  '
clean = normalize_whitespace(raw)
print(f'Before: {raw}\nAfter: {clean}')
