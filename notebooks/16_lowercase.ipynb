# %% [markdown]
# # Phase 3 - Step 27: Lowercasing Module

# %%
import sys
sys.path.append('..')

from src.preprocessing.lowercase import apply_lowercase, batch_lowercase

raw = 'DON\'T Shout HERE! Café 123'
clean = apply_lowercase(raw)
print(f'Before: {raw}\nAfter: {clean}')
