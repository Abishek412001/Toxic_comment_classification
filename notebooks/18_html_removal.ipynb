# %% [markdown]
# # Phase 3 - Step 29: HTML Tag Removal Module

# %%
import sys
sys.path.append('..')

from src.preprocessing.html_cleaner import remove_html_tags

raw = '<p>This is <b>bold</b> text &amp; tags</p>'
clean = remove_html_tags(raw)
print(f'Before: {raw}\nAfter: {clean}')
