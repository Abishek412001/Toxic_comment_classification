# %% [markdown]
# # Phase 5 - Step 61: Multi-Label LSTM Model

# %%
import sys
sys.path.append('..')

from src.models.lstm_model import MultiLabelLSTM
import numpy as np

model = MultiLabelLSTM()
X = np.random.randn(10, 5)
y = np.random.randint(0, 2, size=(10, 6))
model.fit(X, y)
print('LSTM Prediction Shape:', model.predict(X).shape)
