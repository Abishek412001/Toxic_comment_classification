# %% [markdown]
# # Phase 3 - Step 37: Stopword Removal Module

# %%
import sys
sys.path.append('..')

from src.preprocessing.stopword_remover import remove_stopwords

raw = 'this is a toxic comment on wikipedia article'
clean = remove_stopwords(raw)
print(f'Before: {raw}\nAfter: {clean}')
