# %% [markdown]
# # Phase 5 - Step 57: Multi-Label Random Forest

# %%
import sys
sys.path.append('..')

from src.models.random_forest import MultiLabelRandomForest
import numpy as np

model = MultiLabelRandomForest()
X = np.random.randn(10, 5)
y = np.random.randint(0, 2, size=(10, 6))
model.fit(X, y)
print('RF Prediction Shape:', model.predict(X).shape)
