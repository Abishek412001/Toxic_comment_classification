# %% [markdown]
# # Phase 3 - Step 31: Email Address Removal Module

# %%
import sys
sys.path.append('..')

from src.preprocessing.email_cleaner import remove_emails

raw = 'Contact support@domain.com now'
clean = remove_emails(raw, replacement_token='[EMAIL]')
print(f'Before: {raw}\nAfter: {clean}')
