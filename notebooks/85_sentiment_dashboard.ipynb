# %% [markdown]
# # Phase 10 - Step 113: Sentiment Analytics Dashboard

# %%
import sys
sys.path.append('..')

from src.visualization.sentiment_dashboard import SentimentDashboard

SentimentDashboard.render_sentiment_dashboard()
print('Sentiment Dashboard Rendered!')
