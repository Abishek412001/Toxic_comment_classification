# %% [markdown]
# # Phase 3 - Step 28: Contraction Expansion Module

# %%
import sys
sys.path.append('..')

from src.preprocessing.contractions import expand_contractions

raw = 'I don\'t know why he can\'t come'
clean = expand_contractions(raw)
print(f'Before: {raw}\nAfter: {clean}')
