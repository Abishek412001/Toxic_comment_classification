# %% [markdown]
# # Phase 5 - Step 63: Multi-Label GRU Model

# %%
import sys
sys.path.append('..')

from src.models.gru_model import MultiLabelGRU
import numpy as np

model = MultiLabelGRU()
X = np.random.randn(10, 5)
y = np.random.randint(0, 2, size=(10, 6))
model.fit(X, y)
print('GRU Prediction Shape:', model.predict(X).shape)
