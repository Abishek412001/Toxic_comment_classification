# %% [markdown]
# # Phase 3 - Step 30: URL Removal Module

# %%
import sys
sys.path.append('..')

from src.preprocessing.url_cleaner import remove_urls

raw = 'Check out http://example.com for info'
clean = remove_urls(raw, replacement_token='[URL]')
print(f'Before: {raw}\nAfter: {clean}')
