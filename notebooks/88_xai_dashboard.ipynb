# %% [markdown]
# # Phase 10 - Step 116: Explainable AI Analytics Dashboard

# %%
import sys
sys.path.append('..')

from src.visualization.xai_dashboard import XAIDashboardModule

XAIDashboardModule.render_xai_dashboard()
print('XAI Dashboard Rendered!')
