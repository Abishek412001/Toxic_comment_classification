# %% [markdown]
# # Phase 5 - Step 68: Transformer Benchmark Suite

# %%
import sys
sys.path.append('..')

from src.reports.transformer_summary import export_transformer_report

export_transformer_report()
print('Transformer Benchmark Exported!')
