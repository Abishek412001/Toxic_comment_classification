# %% [markdown]
# # Phase 5 - Step 60: Traditional ML Benchmark Suite

# %%
import sys
sys.path.append('..')

from src.reports.traditional_ml_summary import export_traditional_ml_report

export_traditional_ml_report()
print('Traditional ML Benchmark Exported!')
