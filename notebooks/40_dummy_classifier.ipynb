# %% [markdown]
# # Phase 5 - Step 54: Dummy Baseline Classifier

# %%
import sys
sys.path.append('..')

from src.models.dummy_classifier import DummyBaselineClassifier
import numpy as np

model = DummyBaselineClassifier()
X = np.random.randn(10, 5)
y = np.random.randint(0, 2, size=(10, 6))
model.fit(X, y)
print('Dummy Prediction Shape:', model.predict(X).shape)
