# %% [markdown]
# # Phase 7 - Step 88: Enterprise Production Sentiment Pipeline

# %%
import sys
sys.path.append('..')

from src.sentiment.production_sentiment_pipeline import ProductionSentimentPipeline

pipeline = ProductionSentimentPipeline()
res = pipeline.predict_single('Awesome pipeline!')
print('Production Payload:', pipeline.format_rest_payload(res))
