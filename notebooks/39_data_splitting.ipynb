# %% [markdown]
# # Phase 5 - Step 53: Multi-Label Data Splitting Strategy

# %%
import sys
sys.path.append('..')

from src.models.data_splitter import DataSplitter
import numpy as np

splitter = DataSplitter()
X = np.random.randn(100, 10)
y = np.random.randint(0, 2, size=(100, 6))
X_tr, X_va, X_te, y_tr, y_va, y_te = splitter.split(X, y)
print('Train:', len(y_tr), 'Val:', len(y_va), 'Test:', len(y_te))
