# %% [markdown]
# # Phase 10 - Step 112: Toxicity Analytics Dashboard

# %%
import sys
sys.path.append('..')

from src.visualization.toxicity_dashboard import ToxicityDashboard

ToxicityDashboard.render_toxicity_dashboard()
print('Toxicity Dashboard Rendered!')
